# %%
import pandas as pd

df= pd.read_csv("orders.csv")

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
len(df["Country"])
# Out:
# 40

# %%
set(df["Category"])
# Out:
# {'Electronics', 'Furniture', 'Stationery'}

# %%
df[["Country", "Product", "Category"]]
# Out:
#          Country                Product     Category
# 0            USA                 Laptop  Electronics
# 1         Canada             Headphones  Electronics
# 2            UAE           Office Chair    Furniture
# 3      Singapore              Desk Lamp    Furniture
# 4         Mexico               Keyboard  Electronics
# 5            UAE               Notebook   Stationery
# 6             UK          Standing Desk    Furniture
# 7    South Korea                Monitor  Electronics
# 8          Italy                    Pen   Stationery
# 9          Japan                  Mouse  Electronics
# 10        France                 Webcam  Electronics
# 11         India           File Cabinet    Furniture
# 12     Australia                Stapler   Stationery
# 13         Spain              USB Drive  Electronics
# 14         China              Bookshelf    Furniture
# 15         Egypt          Printer Paper   Stationery
# 16        Poland         Wireless Mouse  Electronics
# ...

# %%
df.iloc[5]
# Out:
# OrderID                 1006
# CustomerName    Nora Ibrahim
# Product             Notebook
# Category          Stationery
# Quantity                   5
# Price                    5.0
# OrderDate         2024-06-07
# Shipped                  Yes
# Country                  UAE
# Name: 5, dtype: object

# %%
df.head(2)
# Out:
#    OrderID CustomerName     Product     Category  Quantity   Price  \
# 0     1001   John Smith      Laptop  Electronics         1  1200.0
# 1     1002    Sarah Lee  Headphones  Electronics         2   150.0
#
#     OrderDate Shipped Country
# 0  2024-06-01     Yes     USA
# 1  2024-06-03      No  Canada

# %%
df[(df["Category"] == "Electronics") & (df["Country"] == "USA")]
# Out:
#    OrderID CustomerName Product     Category  Quantity   Price   OrderDate  \
# 0     1001   John Smith  Laptop  Electronics         1  1200.0  2024-06-01
#
#   Shipped Country
# 0     Yes     USA

# %%
df[(df["Category"] == "Electronics") | (df["Country"] == "USA")]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 0      1001        John Smith             Laptop  Electronics         1
# 1      1002         Sarah Lee         Headphones  Electronics         2
# 4      1005     Carlos Mendez           Keyboard  Electronics         2
# 7      1008        James Park            Monitor  Electronics         2
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 10     1011     Sophie Martin             Webcam  Electronics         1
# 13     1014   Diego Rodriguez          USB Drive  Electronics         5
# 16     1017     Anna Kowalski     Wireless Mouse  Electronics         2
# 17     1018     Michael Brown     Desk Organizer    Furniture         1
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 24     1025    Lucas Anderson       Tablet Stand  Electronics         1
# ...

# %%
df[(df["Quantity"] > 5) & (df["Quantity"] <20)]
# Out:
#     OrderID    CustomerName       Product    Category  Quantity  Price  \
# 8      1009     Maria Rossi           Pen  Stationery        10    1.5
# 20     1021  David Thompson  Highlighters  Stationery         8    3.5
# 23     1024      Zara Ahmed  Sticky Notes  Stationery        15    4.0
# 27     1028     Nina Petrov  Binder Clips  Stationery        12    2.5
#
#      OrderDate Shipped   Country
# 8   2024-06-10     Yes     Italy
# 20  2024-06-22      No    Canada
# 23  2024-06-25      No  Pakistan
# 27  2024-06-29     Yes    Russia

# %%
df[df["Country"].isin(["USA", "Brazil", "Germany"])]
# Out:
#     OrderID    CustomerName            Product     Category  Quantity   Price  \
# 0      1001      John Smith             Laptop  Electronics         1  1200.0
# 17     1018   Michael Brown     Desk Organizer    Furniture         1    65.0
# 21     1022  Isabella Silva  Bluetooth Speaker  Electronics         1    95.0
# 22     1023  Oliver Schmidt       Office Plant    Furniture         2    35.0
# 31     1032   Thomas Müller   Document Scanner  Electronics         1   140.0
# 33     1034    Alex Johnson        Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped  Country
# 0   2024-06-01     Yes      USA
# 17  2024-06-19      No      USA
# 21  2024-06-23     Yes   Brazil
# 22  2024-06-24     Yes  Germany
# 31  2024-07-03     Yes  Germany
# 33  2024-07-05     Yes      USA

# %%
df.loc[df["CustomerName"] == "Anna Ivanova", "Product"] = "Another Product"

# %%
df.loc[df["CustomerName"] == "Anna Ivanova"]
# Out:
#     OrderID  CustomerName          Product   Category  Quantity  Price  \
# 39     1040  Anna Ivanova  Another Product  Furniture         1   35.0
#
#      OrderDate Shipped  Country
# 39  2024-07-11     Yes  Ukraine

# %%
df.loc[df["Country"] == "United States", "Country"] = "USA"

# %%
df.loc[df["Country"] == "USA"]
# Out:
#     OrderID   CustomerName         Product     Category  Quantity   Price  \
# 0      1001     John Smith          Laptop  Electronics         1  1200.0
# 17     1018  Michael Brown  Desk Organizer    Furniture         1    65.0
# 33     1034   Alex Johnson     Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped Country
# 0   2024-06-01     Yes     USA
# 17  2024-06-19      No     USA
# 33  2024-07-05     Yes     USA

# %%
df["Country"] = df["Country"].str.upper()

# %%
df["Country"]
# Out:
# 0              USA
# 1           CANADA
# 2              UAE
# 3        SINGAPORE
# 4           MEXICO
# 5              UAE
# 6               UK
# 7      SOUTH KOREA
# 8            ITALY
# 9            JAPAN
# 10          FRANCE
# 11           INDIA
# 12       AUSTRALIA
# 13           SPAIN
# 14           CHINA
# 15           EGYPT
# 16          POLAND
# 17             USA
# 18           JAPAN
# 19    SAUDI ARABIA
# 20          CANADA
# 21          BRAZIL
# 22         GERMANY
# 23        PAKISTAN
# 24          SWEDEN
# 25          FRANCE
# 26       ARGENTINA
# 27          RUSSIA
# 28     SOUTH KOREA
# 29           ITALY
# 30         MOROCCO
# 31         GERMANY
# 32        COLOMBIA
# 33             USA
# 34           JAPAN
# 35              UK
# 36        PORTUGAL
# 37            IRAN
# 38     SOUTH KOREA
# 39         UKRAINE
# Name: Country, dtype: str

# %%
df["Category"].value_counts()
# Out:
# Category
# Electronics    18
# Furniture      14
# Stationery      8
# Name: count, dtype: int64

# %%
df.groupby("Country")["Price"].sum()
# Out:
# Country
# ARGENTINA         22.0
# AUSTRALIA         12.0
# BRAZIL            95.0
# CANADA           153.5
# CHINA            280.0
# COLOMBIA          42.0
# EGYPT              8.0
# FRANCE           160.0
# GERMANY          175.0
# INDIA            180.0
# IRAN              28.0
# ITALY             19.5
# JAPAN            105.0
# MEXICO            80.0
# MOROCCO           32.0
# PAKISTAN           4.0
# POLAND            45.0
# PORTUGAL         125.0
# RUSSIA             2.5
# SAUDI ARABIA     120.0
# SINGAPORE         45.0
# SOUTH KOREA      348.0
# SPAIN             25.0
# SWEDEN            28.0
# UAE              305.0
# UK               518.0
# UKRAINE           35.0
# USA             1265.8
# Name: Price, dtype: float64

# %%
df.to_csv("newFile.csv", index = True)
